# %%
try:
    import torch
    print("✓ PyTorch is successfully imported!")
    print(f"PyTorch version: {torch.__version__}")

    if torch.cuda.is_available():
        print(f"✓ CUDA is available! Device count: {torch.cuda.device_count()}")
        print(f"Current CUDA device: {torch.cuda.get_device_name(0)}")
    else:
        print("CUDA is not available. Using CPU.")

    test_tensor = torch.tensor([1, 2, 3, 4, 5])
    print(f"✓ Test tensor created: {test_tensor}")
    print(f"Tensor shape: {test_tensor.shape}")
    print(f"Tensor device: {test_tensor.device}")

    squared_tensor = test_tensor ** 2
    print(f"✓ Basic operation test (squaring): {squared_tensor}")

    print("\n🎉 PyTorch is working correctly!")

except ImportError as e:
    print("❌ PyTorch is not installed or not available")
    print(f"Error details: {e}")
    print("Please install PyTorch using: pip install torch")

except Exception as e:
    print(f"❌ An error occurred while testing PyTorch: {e}")


# AI Calculation Test Code
try:
    print("\n🔬 Running additional AI computation tests...")

    # 1. Random Matrix Product Test Code
    A = torch.rand((500, 500))
    B = torch.rand((500, 500))
    C = torch.matmul(A, B)
    print("✓ Matrix multiplication test passed!")
    print(f"Result shape: {C.shape}")

    # 2. Simple Neural Network Forward Pass Test Code
    model = torch.nn.Sequential(
        torch.nn.Linear(10, 20),
        torch.nn.ReLU(),
        torch.nn.Linear(20, 5)
    )
    sample_input = torch.randn(1, 10)  # (batch_size=1, features=10)
    output = model(sample_input)
    print("✓ Simple neural network forward pass successful!")
    print(f"Output: {output}")

    # 3. Change GPU Test Code
    if torch.cuda.is_available():
        device = torch.device("cuda")
        model = model.to(device)
        sample_input = sample_input.to(device)
        output = model(sample_input)
        print("✓ Neural network ran successfully on GPU!")
        print(f"Output device: {output.device}")

    print("\n🚀 AI computation tests completed successfully!")

except Exception as e:
    print(f"❌ Error during AI computation tests: {e}")
# Out:
# ✓ PyTorch is successfully imported!
# PyTorch version: 2.8.0+cu126
# ✓ CUDA is available! Device count: 1
# Current CUDA device: Tesla T4
# ✓ Test tensor created: tensor([1, 2, 3, 4, 5])
# Tensor shape: torch.Size([5])
# Tensor device: cpu
# ✓ Basic operation test (squaring): tensor([ 1,  4,  9, 16, 25])
#
# 🎉 PyTorch is working correctly!
#
# 🔬 Running additional AI computation tests...
# ✓ Matrix multiplication test passed!
# Result shape: torch.Size([500, 500])
# ✓ Simple neural network forward pass successful!
# Output: tensor([[ 0.4591, -0.3517, -0.3691,  0.1248, -0.1782]],
#        grad_fn=<AddmmBackward0>)
# ✓ Neural network ran successfully on GPU!
# Output device: cuda:0
#
# 🚀 AI computation tests completed successfully!
